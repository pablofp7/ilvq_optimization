# %%
from river import metrics, naive_bayes, tree, forest
import pandas as pd
from utils import evaluate_model_online_learning, read_dataset, calculate_metrics
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from prototypes_mod.xuilvq import XuILVQ as UpdatedILVQ
import itertools
import multiprocessing

# %%
# Datasets from THU-Concept-Drift-Datasets-v1.0 (replace with actual paths if needed)
dataset_paths = {
    "linear_gradual": "../dataset/linear_gradual_rotation_noise_and_redunce.csv",
    "linear_recurrent": "../dataset/linear_recurrent_rotation_noise_and_redunce.csv",
    "linear_sudden": "../dataset/linear_sudden_rotation_noise_and_redunce.csv",
    # "cake_gradual": "../dataset/nonlinear_gradual_cakerotation_noise_and_redunce.csv",
    # "cake_sudden": "../dataset/nonlinear_sudden_cakerotation_noise_and_redunce.csv",
    # "cake_recurrent": "../dataset/nonlinear_recurrent_cakerotation_noise_and_redunce.csv",
    # "chocolate_gradual": "../dataset/nonlinear_gradual_chocolaterotation_noise_and_redunce.csv",
    # "chocolate_sudden": "../dataset/nonlinear_sudden_chocolaterotation_noise_and_redunce.csv",
    # "chocolate_recurrent": "../dataset/nonlinear_recurrent_chocolaterotation_noise_and_redunce.csv"
}



# Models to use for each dataset
model_factories = {
    "Incremental Learning Vector Quantization": lambda: UpdatedILVQ(),
    "Gaussian Naive Bayes": lambda: naive_bayes.GaussianNB(),
    "Hoeffding Tree": lambda: tree.HoeffdingTreeClassifier(),
    "Adaptive Random Forest": lambda: forest.ARFClassifier(),
}

# %%
# Variables related to the sampling of the dataset

# Step sizes for each dataset (determines how frequently samples are taken)
# step_sizes = {
#     "linear_gradual": 50,
#     "linear_recurrent": 50,
#     "linear_sudden": 50, 
#     # "cake_gradual": 1,
#     # "cake_sudden": 1,
#     # "cake_recurrent": 1,
#     # "chocolate_gradual": 1,
#     # "chocolate_sudden": 1,
#     # "chocolate_recurrent": 1
# }

step_sizes_values = [5, 10, 50, 100, 250, 500, 1000, 2000, 5000, 10000]


# Cycle shift values (how much the starting index shifts per cycle)
cycle_shifts = {
    "linear_gradual": 5,
    "linear_recurrent": 5,
    "linear_sudden": 5,
    # "cake_gradual": 1,
    # "cake_sudden": 1,
    # "cake_recurrent": 1,
    # "chocolate_gradual": 1,
    # "chocolate_sudden": 1,
    # "chocolate_recurrent": 1
}

num_samples = 1000  # Desired number of samples
output_file = "datasets_grid_search_results.txt"  # File to save results

# %%
# cyclic sampling


def cyclic_sampling_with_shift(df, num_samples, step, cycle_shift):
    """
    Performs cyclic sampling with a configurable shift.
    - 'step': Distance between selected samples within a cycle.
    - 'cycle_shift': Shift applied to the starting index of each new cycle.
    """
    total_samples = len(df)
    indices = []
    shift = 0  # Initial shift is 0 (first cycle starts at index 0)

    while len(indices) < num_samples:
        max_per_cycle = total_samples // step  # How many samples per cycle
        
        for i in range(max_per_cycle):
            idx = (shift + i * step) % total_samples  # Wrap around if needed
            indices.append(idx)
            if len(indices) == num_samples:  # Stop if we have enough samples
                break

        shift += cycle_shift  # Increase shift for the next cycle

    sampled_df = df.iloc[indices]
    return sampled_df

# %%
# Load datasets with a specific step size
def load_datasets(step_size):
    datasets = {}
    for name, path in dataset_paths.items():
        try:
            df = read_dataset(name, dataset_paths)
            cycle_shift = cycle_shifts.get(name, 1)  # Default shift = 1 if not defined
            
            df = cyclic_sampling_with_shift(df, num_samples, step_size, cycle_shift)  # Apply cyclic sampling
            
            if len(df) >= num_samples:
                df = df.iloc[:num_samples]
            else:
                print(f"Dataset {name} has only {len(df)} samples after step {step_size}, but {num_samples} were requested.")
            
            datasets[name] = df
            print(f"✅ Loaded {name} (Shape: {df.shape}) - Step {step_size}, Cycle Shift {cycle_shift}, {num_samples} samples taken.")
        except FileNotFoundError:
            print(f"❌ Error: File '{dataset_paths[name]}' not found.")
        except Exception as e:
            print(f"⚠️ Error loading {name}: {e}")
    return datasets

# %%
# Evaluate models for a dataset
def evaluate_models_for_dataset(dataset_name, df, step_size):
    results = []
    print(f"\n\n\n🔍 Evaluating dataset: {dataset_name} with step size {step_size}")

    for model_name, model_factory in model_factories.items():
        model = model_factory()  # Create a new instance of the model
        print(f"🧠 Model: {model_name}")

        # Evaluate using online learning
        try:
            conf_matrix, elapsed_time = evaluate_model_online_learning(model, df)
            metrics_result = calculate_metrics(conf_matrix)

            # Store results
            result_str = (
                f"Dataset: {dataset_name}, Step Size: {step_size}, Model: {model_name}, "
                f"Precision: {metrics_result['precision']}, Recall: {metrics_result['recall']}, "
                f"F1: {metrics_result['f1']}, Execution Time: {elapsed_time:.4f} sec\n"
            )
            results.append(result_str)
            print(result_str)
        except Exception as e:
            print(f"⚠️ An error occurred while processing {dataset_name} with {model_name}: {e}")

    return results

# %%
# Grid Search over step sizes
def grid_search():
    # Ensure the output file starts fresh with a header
    with open(output_file, "w") as f:
        f.write("Dataset, Step Size, Model, Precision, Recall, F1, Execution Time (sec)\n")

    for step_size in step_sizes_values:
        print(f"\n🚀 Running grid search with step size: {step_size}")

        # Load datasets with the current step size
        datasets = load_datasets(step_size)

        # Evaluate models for each dataset
        all_results = []
        for dataset_name, df in datasets.items():
            results = evaluate_models_for_dataset(dataset_name, df, step_size)
            all_results.extend(results)  # Collect results

        # Save results to file
        with open(output_file, "a") as f:
            f.writelines(all_results)
            f.write("\n" + "=" * 80 + "\n\n")  # Separator for readability

# Run the grid search
grid_search()
print(f"\n=== Grid Search Completed! Results saved to '{output_file}' ===")
# Out:
# 🚀 Running grid search with step size: 5
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 5, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 5, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 5, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 5
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 5, Model: Incremental Learning Vector Quantization, Precision: 0.9, Recall: 0.879, F1: 0.889, Execution Time: 0.3598 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 5, Model: Gaussian Naive Bayes, Precision: 0.929, Recall: 0.949, F1: 0.939, Execution Time: 0.0836 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 5, Model: Hoeffding Tree, Precision: 0.887, Recall: 0.93, F1: 0.908, Execution Time: 0.0863 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 5, Model: Adaptive Random Forest, Precision: 0.91, Recall: 0.904, F1: 0.907, Execution Time: 0.8447 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 5
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 5, Model: Incremental Learning Vector Quantization, Precision: 0.89, Recall: 0.904, F1: 0.897, Execution Time: 0.3454 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 5, Model: Gaussian Naive Bayes, Precision: 0.946, Recall: 0.963, F1: 0.954, Execution Time: 0.0836 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 5, Model: Hoeffding Tree, Precision: 0.946, Recall: 0.961, F1: 0.953, Execution Time: 0.0857 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 5, Model: Adaptive Random Forest, Precision: 0.894, Recall: 0.898, F1: 0.896, Execution Time: 0.8162 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 5
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 5, Model: Incremental Learning Vector Quantization, Precision: 0.83, Recall: 0.907, F1: 0.867, Execution Time: 0.5162 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 5, Model: Gaussian Naive Bayes, Precision: 0.942, Recall: 0.958, F1: 0.95, Execution Time: 0.0850 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 5, Model: Hoeffding Tree, Precision: 0.942, Recall: 0.957, F1: 0.949, Execution Time: 0.0865 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 5, Model: Adaptive Random Forest, Precision: 0.913, Recall: 0.929, F1: 0.921, Execution Time: 0.8431 sec
#
#
# 🚀 Running grid search with step size: 10
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 10, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 10, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 10, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 10
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 10, Model: Incremental Learning Vector Quantization, Precision: 0.917, Recall: 0.899, F1: 0.908, Execution Time: 0.3113 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 10, Model: Gaussian Naive Bayes, Precision: 0.947, Recall: 0.946, F1: 0.946, Execution Time: 0.0851 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 10, Model: Hoeffding Tree, Precision: 0.918, Recall: 0.94, F1: 0.929, Execution Time: 0.0852 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 10, Model: Adaptive Random Forest, Precision: 0.936, Recall: 0.911, F1: 0.923, Execution Time: 0.8261 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 10
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 10, Model: Incremental Learning Vector Quantization, Precision: 0.913, Recall: 0.804, F1: 0.855, Execution Time: 0.6287 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 10, Model: Gaussian Naive Bayes, Precision: 0.943, Recall: 0.919, F1: 0.931, Execution Time: 0.0840 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 10, Model: Hoeffding Tree, Precision: 0.943, Recall: 0.919, F1: 0.931, Execution Time: 0.0856 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 10, Model: Adaptive Random Forest, Precision: 0.873, Recall: 0.893, F1: 0.883, Execution Time: 0.8537 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 10
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 10, Model: Incremental Learning Vector Quantization, Precision: 0.895, Recall: 0.847, F1: 0.87, Execution Time: 0.5649 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 10, Model: Gaussian Naive Bayes, Precision: 0.968, Recall: 0.944, F1: 0.956, Execution Time: 0.0832 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 10, Model: Hoeffding Tree, Precision: 0.97, Recall: 0.93, F1: 0.95, Execution Time: 0.0846 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 10, Model: Adaptive Random Forest, Precision: 0.878, Recall: 0.849, F1: 0.863, Execution Time: 0.8635 sec
#
#
# 🚀 Running grid search with step size: 50
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 50, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 50, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 50, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 50
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 50, Model: Incremental Learning Vector Quantization, Precision: 0.849, Recall: 0.875, F1: 0.862, Execution Time: 0.5499 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 50, Model: Gaussian Naive Bayes, Precision: 0.906, Recall: 0.886, F1: 0.896, Execution Time: 0.0862 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 50, Model: Hoeffding Tree, Precision: 0.907, Recall: 0.867, F1: 0.887, Execution Time: 0.0804 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 50, Model: Adaptive Random Forest, Precision: 0.888, Recall: 0.873, F1: 0.88, Execution Time: 0.8357 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 50
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 50, Model: Incremental Learning Vector Quantization, Precision: 0.82, Recall: 0.919, F1: 0.867, Execution Time: 0.3187 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 50, Model: Gaussian Naive Bayes, Precision: 0.895, Recall: 0.917, F1: 0.906, Execution Time: 0.0856 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 50, Model: Hoeffding Tree, Precision: 0.882, Recall: 0.894, F1: 0.888, Execution Time: 0.0858 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 50, Model: Adaptive Random Forest, Precision: 0.856, Recall: 0.879, F1: 0.867, Execution Time: 0.8480 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 50
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 50, Model: Incremental Learning Vector Quantization, Precision: 0.859, Recall: 0.826, F1: 0.842, Execution Time: 0.4538 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 50, Model: Gaussian Naive Bayes, Precision: 0.879, Recall: 0.879, F1: 0.879, Execution Time: 0.0871 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 50, Model: Hoeffding Tree, Precision: 0.899, Recall: 0.881, F1: 0.89, Execution Time: 0.0837 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 50, Model: Adaptive Random Forest, Precision: 0.885, Recall: 0.858, F1: 0.871, Execution Time: 0.8658 sec
#
#
# 🚀 Running grid search with step size: 100
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 100, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 100, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 100, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 100
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 100, Model: Incremental Learning Vector Quantization, Precision: 0.8, Recall: 0.773, F1: 0.786, Execution Time: 0.6297 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 100, Model: Gaussian Naive Bayes, Precision: 0.755, Recall: 0.759, F1: 0.757, Execution Time: 0.0881 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 100, Model: Hoeffding Tree, Precision: 0.759, Recall: 0.795, F1: 0.777, Execution Time: 0.0861 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 100, Model: Adaptive Random Forest, Precision: 0.846, Recall: 0.851, F1: 0.848, Execution Time: 0.8694 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 100
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 100, Model: Incremental Learning Vector Quantization, Precision: 0.881, Recall: 0.85, F1: 0.865, Execution Time: 0.6909 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 100, Model: Gaussian Naive Bayes, Precision: 0.906, Recall: 0.913, F1: 0.909, Execution Time: 0.0857 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 100, Model: Hoeffding Tree, Precision: 0.913, Recall: 0.889, F1: 0.901, Execution Time: 0.0875 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 100, Model: Adaptive Random Forest, Precision: 0.882, Recall: 0.887, F1: 0.884, Execution Time: 0.9151 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 100
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 100, Model: Incremental Learning Vector Quantization, Precision: 0.682, Recall: 0.674, F1: 0.678, Execution Time: 0.2477 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 100, Model: Gaussian Naive Bayes, Precision: 0.732, Recall: 0.735, F1: 0.733, Execution Time: 0.0859 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 100, Model: Hoeffding Tree, Precision: 0.853, Recall: 0.849, F1: 0.851, Execution Time: 0.0933 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 100, Model: Adaptive Random Forest, Precision: 0.827, Recall: 0.809, F1: 0.818, Execution Time: 0.8954 sec
#
#
# 🚀 Running grid search with step size: 250
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 250, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 250, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 250, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 250
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 250, Model: Incremental Learning Vector Quantization, Precision: 0.7, Recall: 0.815, F1: 0.753, Execution Time: 0.4602 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 250, Model: Gaussian Naive Bayes, Precision: 0.786, Recall: 0.729, F1: 0.756, Execution Time: 0.0850 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 250, Model: Hoeffding Tree, Precision: 0.774, Recall: 0.774, F1: 0.774, Execution Time: 0.0861 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 250, Model: Adaptive Random Forest, Precision: 0.772, Recall: 0.725, F1: 0.748, Execution Time: 0.9338 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 250
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 250, Model: Incremental Learning Vector Quantization, Precision: 0.814, Recall: 0.914, F1: 0.861, Execution Time: 0.5846 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 250, Model: Gaussian Naive Bayes, Precision: 0.917, Recall: 0.919, F1: 0.918, Execution Time: 0.0841 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 250, Model: Hoeffding Tree, Precision: 0.905, Recall: 0.874, F1: 0.889, Execution Time: 0.0833 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 250, Model: Adaptive Random Forest, Precision: 0.892, Recall: 0.904, F1: 0.898, Execution Time: 0.8157 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 250
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 250, Model: Incremental Learning Vector Quantization, Precision: 0.728, Recall: 0.706, F1: 0.717, Execution Time: 0.8243 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 250, Model: Gaussian Naive Bayes, Precision: 0.749, Recall: 0.753, F1: 0.751, Execution Time: 0.0848 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 250, Model: Hoeffding Tree, Precision: 0.755, Recall: 0.793, F1: 0.774, Execution Time: 0.0876 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 250, Model: Adaptive Random Forest, Precision: 0.732, Recall: 0.71, F1: 0.721, Execution Time: 0.9514 sec
#
#
# 🚀 Running grid search with step size: 500
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 500, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 500, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 500, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 500
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 500, Model: Incremental Learning Vector Quantization, Precision: 0.689, Recall: 0.712, F1: 0.7, Execution Time: 0.7835 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 500, Model: Gaussian Naive Bayes, Precision: 0.728, Recall: 0.714, F1: 0.721, Execution Time: 0.0842 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 500, Model: Hoeffding Tree, Precision: 0.728, Recall: 0.71, F1: 0.719, Execution Time: 0.0866 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 500, Model: Adaptive Random Forest, Precision: 0.675, Recall: 0.696, F1: 0.685, Execution Time: 0.8890 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 500
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 500, Model: Incremental Learning Vector Quantization, Precision: 0.856, Recall: 0.817, F1: 0.836, Execution Time: 0.6336 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 500, Model: Gaussian Naive Bayes, Precision: 0.905, Recall: 0.911, F1: 0.908, Execution Time: 0.0843 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 500, Model: Hoeffding Tree, Precision: 0.895, Recall: 0.874, F1: 0.884, Execution Time: 0.0859 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 500, Model: Adaptive Random Forest, Precision: 0.873, Recall: 0.905, F1: 0.889, Execution Time: 0.8318 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 500
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 500, Model: Incremental Learning Vector Quantization, Precision: 0.699, Recall: 0.656, F1: 0.677, Execution Time: 0.6554 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 500, Model: Gaussian Naive Bayes, Precision: 0.72, Recall: 0.701, F1: 0.71, Execution Time: 0.0841 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 500, Model: Hoeffding Tree, Precision: 0.718, Recall: 0.703, F1: 0.71, Execution Time: 0.0851 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 500, Model: Adaptive Random Forest, Precision: 0.703, Recall: 0.674, F1: 0.688, Execution Time: 0.9220 sec
#
#
# 🚀 Running grid search with step size: 1000
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 1000, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 1000, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 1000, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 1000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 1000, Model: Incremental Learning Vector Quantization, Precision: 0.671, Recall: 0.692, F1: 0.681, Execution Time: 0.7135 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 1000, Model: Gaussian Naive Bayes, Precision: 0.705, Recall: 0.74, F1: 0.722, Execution Time: 0.0837 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 1000, Model: Hoeffding Tree, Precision: 0.703, Recall: 0.738, F1: 0.72, Execution Time: 0.0840 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 1000, Model: Adaptive Random Forest, Precision: 0.67, Recall: 0.72, F1: 0.694, Execution Time: 0.8534 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 1000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 1000, Model: Incremental Learning Vector Quantization, Precision: 0.855, Recall: 0.815, F1: 0.835, Execution Time: 0.5841 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 1000, Model: Gaussian Naive Bayes, Precision: 0.861, Recall: 0.876, F1: 0.868, Execution Time: 0.0834 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 1000, Model: Hoeffding Tree, Precision: 0.866, Recall: 0.827, F1: 0.846, Execution Time: 0.0847 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 1000, Model: Adaptive Random Forest, Precision: 0.828, Recall: 0.835, F1: 0.831, Execution Time: 0.8661 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 1000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 1000, Model: Incremental Learning Vector Quantization, Precision: 0.635, Recall: 0.586, F1: 0.61, Execution Time: 0.7827 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 1000, Model: Gaussian Naive Bayes, Precision: 0.701, Recall: 0.642, F1: 0.67, Execution Time: 0.0843 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 1000, Model: Hoeffding Tree, Precision: 0.699, Recall: 0.642, F1: 0.669, Execution Time: 0.0851 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 1000, Model: Adaptive Random Forest, Precision: 0.704, Recall: 0.607, F1: 0.652, Execution Time: 0.8450 sec
#
#
# 🚀 Running grid search with step size: 2000
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 2000, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 2000, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 2000, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 2000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 2000, Model: Incremental Learning Vector Quantization, Precision: 0.655, Recall: 0.667, F1: 0.661, Execution Time: 0.7407 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 2000, Model: Gaussian Naive Bayes, Precision: 0.731, Recall: 0.752, F1: 0.741, Execution Time: 0.0848 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 2000, Model: Hoeffding Tree, Precision: 0.732, Recall: 0.75, F1: 0.741, Execution Time: 0.0861 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 2000, Model: Adaptive Random Forest, Precision: 0.683, Recall: 0.715, F1: 0.699, Execution Time: 0.8605 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 2000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 2000, Model: Incremental Learning Vector Quantization, Precision: 0.832, Recall: 0.859, F1: 0.845, Execution Time: 0.5207 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 2000, Model: Gaussian Naive Bayes, Precision: 0.857, Recall: 0.877, F1: 0.867, Execution Time: 0.0856 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 2000, Model: Hoeffding Tree, Precision: 0.859, Recall: 0.811, F1: 0.834, Execution Time: 0.0832 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 2000, Model: Adaptive Random Forest, Precision: 0.858, Recall: 0.837, F1: 0.847, Execution Time: 0.8606 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 2000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 2000, Model: Incremental Learning Vector Quantization, Precision: 0.67, Recall: 0.657, F1: 0.663, Execution Time: 0.7789 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 2000, Model: Gaussian Naive Bayes, Precision: 0.724, Recall: 0.705, F1: 0.714, Execution Time: 0.0833 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 2000, Model: Hoeffding Tree, Precision: 0.723, Recall: 0.701, F1: 0.712, Execution Time: 0.0856 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 2000, Model: Adaptive Random Forest, Precision: 0.679, Recall: 0.655, F1: 0.667, Execution Time: 0.8537 sec
#
#
# 🚀 Running grid search with step size: 5000
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 5000, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 5000, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 5000, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 5000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 5000, Model: Incremental Learning Vector Quantization, Precision: 0.67, Recall: 0.77, F1: 0.717, Execution Time: 0.2718 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 5000, Model: Gaussian Naive Bayes, Precision: 0.703, Recall: 0.729, F1: 0.716, Execution Time: 0.0841 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 5000, Model: Hoeffding Tree, Precision: 0.698, Recall: 0.733, F1: 0.715, Execution Time: 0.0850 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 5000, Model: Adaptive Random Forest, Precision: 0.699, Recall: 0.764, F1: 0.73, Execution Time: 0.8465 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 5000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 5000, Model: Incremental Learning Vector Quantization, Precision: 0.849, Recall: 0.842, F1: 0.845, Execution Time: 0.7677 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 5000, Model: Gaussian Naive Bayes, Precision: 0.874, Recall: 0.86, F1: 0.867, Execution Time: 0.0834 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 5000, Model: Hoeffding Tree, Precision: 0.83, Recall: 0.874, F1: 0.851, Execution Time: 0.0828 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 5000, Model: Adaptive Random Forest, Precision: 0.848, Recall: 0.87, F1: 0.859, Execution Time: 0.8205 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 5000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 5000, Model: Incremental Learning Vector Quantization, Precision: 0.654, Recall: 0.639, F1: 0.646, Execution Time: 0.6974 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 5000, Model: Gaussian Naive Bayes, Precision: 0.717, Recall: 0.679, F1: 0.697, Execution Time: 0.0842 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 5000, Model: Hoeffding Tree, Precision: 0.717, Recall: 0.648, F1: 0.681, Execution Time: 0.0860 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 5000, Model: Adaptive Random Forest, Precision: 0.678, Recall: 0.61, F1: 0.642, Execution Time: 0.9784 sec
#
#
# 🚀 Running grid search with step size: 10000
# ✅ Loaded linear_gradual (Shape: (1000, 6)) - Step 10000, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_recurrent (Shape: (1000, 6)) - Step 10000, Cycle Shift 5, 1000 samples taken.
# ✅ Loaded linear_sudden (Shape: (1000, 6)) - Step 10000, Cycle Shift 5, 1000 samples taken.
#
#
#
# 🔍 Evaluating dataset: linear_gradual with step size 10000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_gradual, Step Size: 10000, Model: Incremental Learning Vector Quantization, Precision: 0.725, Recall: 0.682, F1: 0.703, Execution Time: 0.3404 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_gradual, Step Size: 10000, Model: Gaussian Naive Bayes, Precision: 0.743, Recall: 0.72, F1: 0.731, Execution Time: 0.0845 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_gradual, Step Size: 10000, Model: Hoeffding Tree, Precision: 0.741, Recall: 0.722, F1: 0.731, Execution Time: 0.0855 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_gradual, Step Size: 10000, Model: Adaptive Random Forest, Precision: 0.713, Recall: 0.663, F1: 0.687, Execution Time: 0.8517 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_recurrent with step size 10000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_recurrent, Step Size: 10000, Model: Incremental Learning Vector Quantization, Precision: 0.846, Recall: 0.871, F1: 0.858, Execution Time: 0.5983 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_recurrent, Step Size: 10000, Model: Gaussian Naive Bayes, Precision: 0.891, Recall: 0.875, F1: 0.883, Execution Time: 0.0830 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_recurrent, Step Size: 10000, Model: Hoeffding Tree, Precision: 0.821, Recall: 0.857, F1: 0.839, Execution Time: 0.0811 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_recurrent, Step Size: 10000, Model: Adaptive Random Forest, Precision: 0.848, Recall: 0.861, F1: 0.854, Execution Time: 0.8270 sec
#
#
#
#
# 🔍 Evaluating dataset: linear_sudden with step size 10000
# 🧠 Model: Incremental Learning Vector Quantization
# Dataset: linear_sudden, Step Size: 10000, Model: Incremental Learning Vector Quantization, Precision: 0.709, Recall: 0.64, F1: 0.673, Execution Time: 0.2226 sec
#
# 🧠 Model: Gaussian Naive Bayes
# Dataset: linear_sudden, Step Size: 10000, Model: Gaussian Naive Bayes, Precision: 0.744, Recall: 0.696, F1: 0.719, Execution Time: 0.0844 sec
#
# 🧠 Model: Hoeffding Tree
# Dataset: linear_sudden, Step Size: 10000, Model: Hoeffding Tree, Precision: 0.748, Recall: 0.677, F1: 0.711, Execution Time: 0.0853 sec
#
# 🧠 Model: Adaptive Random Forest
# Dataset: linear_sudden, Step Size: 10000, Model: Adaptive Random Forest, Precision: 0.699, Recall: 0.687, F1: 0.693, Execution Time: 0.8989 sec
#
#
# === Grid Search Completed! Results saved to 'datasets_grid_search_results.txt' ===
